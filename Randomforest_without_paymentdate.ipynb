# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as spstats

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df = pd.read_csv("C://DataScience//Regis24/unique_orders.csv")
df.drop(columns = ['ORDER_ID', 'CUSTOMER_ID', 'delay_duration','NR_ITEMS_UNIQUE', 'NR_ITEMS',
                   'total_orders', 'paytime', 'rank','payment_duration' ], inplace=True)

# %%
# Monday is 0 and Sunday is 6

df['ORDER_DATE'] = pd.to_datetime(df['ORDER_DATE'])
df['ORDER_DATE_year'] = df['ORDER_DATE'].dt.year#2
df['ORDER_DATE_month'] = df['ORDER_DATE'].dt.month#3
df['ORDER_DATE_day'] = df['ORDER_DATE'].dt.day#2
df['ORDER_DATE_day_of_week'] = df['ORDER_DATE'].dt.dayofweek
df['ORDER_DATE_is_month_start'] = df['ORDER_DATE'].dt.is_month_start
df['ORDER_DATE_is_month_end'] = df['ORDER_DATE'].dt.is_month_end
df['ORDER_DATE_is_weekend'] = np.where(df['ORDER_DATE_day_of_week'].isin([5,6]), 1, 0)
df['ORDER_DATE_is_month_end'] = df['ORDER_DATE_is_month_end'].astype(str)
df['ORDER_DATE_is_month_start'] = df['ORDER_DATE_is_month_start'].astype(str)

# %%
df.drop(columns = ['PAYMENT_DATE','ORDER_DATE'], inplace=True)

# %%
# drop these rows having cart value above 1000
# from dataFrame
df = df.drop(df[df['CART_VALUE'] > 800].index)
df.shape
# Out:
# (1681198, 14)

# %%
df['CART_VALUE']= round(df['CART_VALUE'])
len(df['CART_VALUE'].unique())
# Out:
# 801

# %%
df.shape
# Out:
# (1681198, 14)

# %% [markdown]
# ### SPLIT DATA INTO TRAIN AND TEST

# %%
#Splitting the dataset to Test and Train
from sklearn.model_selection import train_test_split

X = df.drop(['delay_category'], axis= 1)
y = df['delay_category']
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=.2)
X_train = X_train.copy()

# %%
### Normalize the pay_duration, age and Cart_value

# %%
y_train = pd.DataFrame(y_train)

# %%
from sklearn import preprocessing
min_max = preprocessing.MinMaxScaler()

# %%
# copy the data
X_train_min_max_scaled = X_train.copy()
  
# apply normalization techniques by Column 
column = 'AGE'
X_train_min_max_scaled[column] = (X_train_min_max_scaled[column] - X_train_min_max_scaled[column].min()) / (X_train_min_max_scaled[column].max() - X_train_min_max_scaled[column].min())    

column = 'CART_VALUE'
X_train_min_max_scaled[column] = (X_train_min_max_scaled[column] - X_train_min_max_scaled[column].min()) / (X_train_min_max_scaled[column].max() - X_train_min_max_scaled[column].min())

# %%
# Test data same steps:
X_train = X_train_min_max_scaled
X_train.shape
# Out:
# (1344958, 13)

# %%
from sklearn.preprocessing import LabelEncoder
# Instantiate LabelEncoder
le = LabelEncoder()

# %%
cols = ['ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week' ]

# Encode labels of multiple columns at once
X_train[cols] = X_train[cols].apply(le.fit_transform)

# %%
dummies_X_Train = pd.get_dummies(X_train[['ORDER_DATE_is_month_start',
        'ORDER_DATE_is_month_end', 'ORDER_DATE_is_weekend','SHOP', 
        'PAYMENT_INFO', 'GENDER','Default_Flag']])

# %%
dummies_X_Train.shape
# Out:
# (1344958, 27)

# %%
dummies_X_Train.join(X_train[['AGE','CART_VALUE', 'ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week' ]])
# Out:
#          ORDER_DATE_is_weekend  Default_Flag  ORDER_DATE_is_month_start_False  \
# 1554985                      0             0                                1
# 1191845                      0             0                                1
# 804690                       1             0                                1
# 330517                       0             0                                1
# 437840                       1             0                                1
# ...                        ...           ...                              ...
# 950319                       0             0                                1
# 441823                       0             0                                1
# 570552                       0             0                                1
# 1265554                      0             0                                1
# 1223501                      0             0                                1
#
#          ORDER_DATE_is_month_start_True  ORDER_DATE_is_month_end_False  \
# 1554985                               0                              1
# 1191845                               0                              1
# 804690                                0                              1
# 330517                                0                              1
# 437840                                0                              1
# ...                                 ...                            ...
# 950319                                0                              1
# 441823                                0                              1
# 570552                                0                              1
# 1265554                               0                              1
# 1223501                               0                              1
#
#          ORDER_DATE_is_month_end_True  SHOP_Baby & Child  \
# 1554985                             0                  0
# 1191845                             0                  0
# 804690                              0                  0
# 330517                              0                  0
# 437840                              0                  0
# ...                               ...                ...
# 950319                              0                  0
# 441823                              0                  0
# 570552                              0                  0
# 1265554                             0                  0
# 1223501                             0                  0
#
#          SHOP_Car Accessories  SHOP_DIY Superstore & Tools  SHOP_Electronics  \
# 1554985                     0                            0                 0
# 1191845                     0                            0                 0
# 804690                      0                            0                 0
# 330517                      0                            1                 0
# 437840                      0                            0                 0
# ...                       ...                          ...               ...
# 950319                      0                            0                 0
# 441823                      0                            0                 0
# 570552                      0                            0                 0
# 1265554                     0                            0                 0
# 1223501                     0                            1                 0
#
#          SHOP_Fashion  SHOP_Food  SHOP_Furniture  SHOP_Jewellery  SHOP_Media  \
# 1554985             0          0               0               0           0
# 1191845             0          0               0               0           0
# 804690              1          0               0               0           0
# 330517              0          0               0               0           0
# 437840              1          0               0               0           0
# ...               ...        ...             ...             ...         ...
# 950319              0          0               0               0           0
# 441823              1          0               0               0           0
# 570552              1          0               0               0           0
# 1265554             1          0               0               0           0
# 1223501             0          0               0               0           0
#
#          SHOP_Shoes  SHOP_Sports  SHOP_Toys  SHOP_Young Fashion  \
# 1554985           0            0          0                   1
# 1191845           0            1          0                   0
# 804690            0            0          0                   0
# 330517            0            0          0                   0
# 437840            0            0          0                   0
# ...             ...          ...        ...                 ...
# 950319            0            0          1                   0
# 441823            0            0          0                   0
# 570552            0            0          0                   0
# 1265554           0            0          0                   0
# 1223501           0            0          0                   0
#
#          PAYMENT_INFO_CONTRACT_TERMINATION  PAYMENT_INFO_INKASSO_CLOSED  \
# 1554985                                  0                            0
# 1191845                                  0                            0
# 804690                                   0                            0
# 330517                                   0                            0
# 437840                                   0                            0
# ...                                    ...                          ...
# 950319                                   0                            0
# 441823                                   0                            0
# 570552                                   0                            0
# 1265554                                  0                            0
# 1223501                                  0                            0
#
#          PAYMENT_INFO_INKASSO_PENDING  PAYMENT_INFO_PAID_FULL  \
# 1554985                             0                       1
# 1191845                             0                       1
# 804690                              0                       1
# 330517                              0                       1
# 437840                              0                       1
# ...                               ...                     ...
# 950319                              0                       1
# 441823                              0                       1
# 570552                              0                       1
# 1265554                             0                       1
# 1223501                             0                       1
#
#          PAYMENT_INFO_PAID_OVER  GENDER_f  GENDER_m  GENDER_u       AGE  \
# 1554985                       0         0         1         0  0.230769
# 1191845                       0         0         1         0  0.256410
# 804690                        0         1         0         0  0.316239
# 330517                        0         0         1         0  0.538462
# 437840                        0         1         0         0  0.307692
# ...                         ...       ...       ...       ...       ...
# 950319                        0         1         0         0  0.264957
# 441823                        0         1         0         0  0.495726
# 570552                        0         1         0         0  0.435897
# 1265554                       0         1         0         0  0.658120
# 1223501                       0         0         1         0  0.632479
#
#          CART_VALUE  ORDER_DATE_year  ORDER_DATE_month  ORDER_DATE_day  \
# 1554985     0.06250                4                11              13
# 1191845     0.22125                4                 6              16
# 804690      0.35500                3                 7              24
# 330517      0.04125                2                 4              28
# 437840      0.08250                2                 8              21
# ...             ...              ...               ...             ...
# 950319      0.04500                3                11              17
# 441823      0.15000                2                 8              25
# 570552      0.20750                3                 0              29
# 1265554     0.25750                4                 6               6
# 1223501     0.04875                4                 5              17
#
#          ORDER_DATE_day_of_week
# 1554985                       0
# 1191845                       4
# 804690                        6
# 330517                        1
# 437840                        5
# ...                         ...
# 950319                        2
# 441823                        2
# 570552                        2
# 1265554                       1
# 1223501                       3
#
# [1344958 rows x 33 columns]

# %%
X_train_final = dummies_X_Train.join(X_train[['AGE','CART_VALUE',
        'ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week' ]])

# %%
X_train_final.shape
# Out:
# (1344958, 33)

# %%
X_train_columnlist = X_train.columns
X_train.columns
# Out:
# Index(['PAYMENT_INFO', 'SHOP', 'AGE', 'CART_VALUE', 'GENDER', 'Default_Flag',
#        'ORDER_DATE_year', 'ORDER_DATE_month', 'ORDER_DATE_day',
#        'ORDER_DATE_day_of_week', 'ORDER_DATE_is_month_start',
#        'ORDER_DATE_is_month_end', 'ORDER_DATE_is_weekend'],
#       dtype='object')

# %%
# Encode labels of multiple columns at once

y_train = y_train.apply(le.fit_transform)

# Print head
y_train.head(3)
# Out:
#          delay_category
# 1554985               4
# 1191845               4
# 804690                0

# %% [markdown]
# # Test Data

# %%
# copy the data
# copy the data
X_test_min_max_scaled = X_test.copy()
  
# apply normalization techniques by Column 
column = 'AGE'
X_test_min_max_scaled[column] = (X_test_min_max_scaled[column] - X_test_min_max_scaled[column].min()) / (X_test_min_max_scaled[column].max() - X_test_min_max_scaled[column].min())    
column = 'CART_VALUE'
X_test_min_max_scaled[column] = (X_test_min_max_scaled[column] - X_test_min_max_scaled[column].min()) / (X_test_min_max_scaled[column].max() - X_test_min_max_scaled[column].min())

# %%
# Test data same steps:
X_test = X_test_min_max_scaled
X_test.shape
# Out:
# (336240, 13)

# %%
cols = ['ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week' ]

# Encode labels of multiple columns at once
X_test[cols] = X_test[cols].apply(le.fit_transform)

# %%
dummies_X_Test = pd.get_dummies(X_test[['ORDER_DATE_is_month_start',
        'ORDER_DATE_is_month_end', 'ORDER_DATE_is_weekend','SHOP', 
        'PAYMENT_INFO', 'GENDER','Default_Flag']])

# %%
dummies_X_Train.shape
# Out:
# (1344958, 27)

# %%
dummies_X_Test.join(X_test[['AGE','CART_VALUE',
        'ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week'  ]])
# Out:
#          ORDER_DATE_is_weekend  Default_Flag  ORDER_DATE_is_month_start_False  \
# 1657786                      0             0                                1
# 1426112                      0             0                                1
# 573365                       1             0                                1
# 744536                       0             0                                1
# 177267                       0             0                                1
# ...                        ...           ...                              ...
# 1497957                      0             0                                1
# 209227                       0             0                                1
# 179080                       1             0                                1
# 1032146                      0             0                                1
# 1451794                      0             0                                1
#
#          ORDER_DATE_is_month_start_True  ORDER_DATE_is_month_end_False  \
# 1657786                               0                              1
# 1426112                               0                              1
# 573365                                0                              1
# 744536                                0                              1
# 177267                                0                              1
# ...                                 ...                            ...
# 1497957                               0                              1
# 209227                                0                              1
# 179080                                0                              1
# 1032146                               0                              1
# 1451794                               0                              1
#
#          ORDER_DATE_is_month_end_True  SHOP_Baby & Child  \
# 1657786                             0                  0
# 1426112                             0                  0
# 573365                              0                  0
# 744536                              0                  0
# 177267                              0                  0
# ...                               ...                ...
# 1497957                             0                  0
# 209227                              0                  0
# 179080                              0                  0
# 1032146                             0                  0
# 1451794                             0                  0
#
#          SHOP_Car Accessories  SHOP_DIY Superstore & Tools  SHOP_Electronics  \
# 1657786                     0                            0                 0
# 1426112                     0                            0                 0
# 573365                      0                            0                 0
# 744536                      0                            0                 0
# 177267                      0                            1                 0
# ...                       ...                          ...               ...
# 1497957                     0                            0                 0
# 209227                      0                            0                 0
# 179080                      0                            0                 0
# 1032146                     0                            0                 0
# 1451794                     0                            0                 0
#
#          SHOP_Fashion  SHOP_Food  SHOP_Furniture  SHOP_Jewellery  SHOP_Media  \
# 1657786             1          0               0               0           0
# 1426112             1          0               0               0           0
# 573365              0          0               0               0           0
# 744536              1          0               0               0           0
# 177267              0          0               0               0           0
# ...               ...        ...             ...             ...         ...
# 1497957             1          0               0               0           0
# 209227              0          0               0               0           0
# 179080              0          0               0               1           0
# 1032146             1          0               0               0           0
# 1451794             0          1               0               0           0
#
#          SHOP_Shoes  SHOP_Sports  SHOP_Toys  SHOP_Young Fashion  \
# 1657786           0            0          0                   0
# 1426112           0            0          0                   0
# 573365            0            1          0                   0
# 744536            0            0          0                   0
# 177267            0            0          0                   0
# ...             ...          ...        ...                 ...
# 1497957           0            0          0                   0
# 209227            0            0          1                   0
# 179080            0            0          0                   0
# 1032146           0            0          0                   0
# 1451794           0            0          0                   0
#
#          PAYMENT_INFO_CONTRACT_TERMINATION  PAYMENT_INFO_INKASSO_CLOSED  \
# 1657786                                  0                            0
# 1426112                                  0                            0
# 573365                                   0                            0
# 744536                                   0                            0
# 177267                                   0                            0
# ...                                    ...                          ...
# 1497957                                  0                            0
# 209227                                   0                            0
# 179080                                   0                            0
# 1032146                                  0                            0
# 1451794                                  0                            0
#
#          PAYMENT_INFO_INKASSO_PENDING  PAYMENT_INFO_PAID_FULL  \
# 1657786                             0                       1
# 1426112                             0                       0
# 573365                              0                       1
# 744536                              0                       1
# 177267                              0                       1
# ...                               ...                     ...
# 1497957                             0                       1
# 209227                              0                       1
# 179080                              0                       1
# 1032146                             0                       1
# 1451794                             0                       1
#
#          PAYMENT_INFO_PAID_OVER  GENDER_f  GENDER_m  GENDER_u       AGE  \
# 1657786                       0         1         0         0  0.426087
# 1426112                       1         1         0         0  0.513043
# 573365                        0         1         0         0  0.521739
# 744536                        0         1         0         0  0.330435
# 177267                        0         1         0         0  0.556522
# ...                         ...       ...       ...       ...       ...
# 1497957                       0         0         1         0  0.460870
# 209227                        0         1         0         0  0.347826
# 179080                        0         0         1         0  0.356522
# 1032146                       0         1         0         0  0.513043
# 1451794                       0         0         1         0  0.243478
#
#          CART_VALUE  ORDER_DATE_year  ORDER_DATE_month  ORDER_DATE_day  \
# 1657786     0.06375                5                 1               8
# 1426112     0.08375                4                 9               7
# 573365      0.10000                3                 1               1
# 744536      0.39875                3                 6               3
# 177267      0.11625                1                10               9
# ...             ...              ...               ...             ...
# 1497957     0.05750                4                10              16
# 209227      0.06375                1                11              10
# 179080      0.06875                1                10              11
# 1032146     0.02125                4                 1              17
# 1451794     0.03500                4                 9              21
#
#          ORDER_DATE_day_of_week
# 1657786                       1
# 1426112                       3
# 573365                        5
# 744536                        3
# 177267                        4
# ...                         ...
# 1497957                       1
# 209227                        0
# 179080                        6
# 1032146                       1
# 1451794                       3
#
# [336240 rows x 33 columns]

# %%
X_test_final = dummies_X_Test.join(X_test[['AGE','CART_VALUE',
        'ORDER_DATE_year','ORDER_DATE_month','ORDER_DATE_day','ORDER_DATE_day_of_week'  ]])

# %%
y_test = pd.DataFrame(y_test)

# %%
# Encode labels of multiple columns at once

y_test = y_test.apply(le.fit_transform)

# Print head
y_test.head(3)
# Out:
#          delay_category
# 1657786               4
# 1426112               4
# 573365                4

# %%
list(le.classes_)
# Out:
# ['1-14 days', '15-29 days', '30-59 days', '60+ days', 'On Time']

# %% [markdown]
# ### Check the final X and y and train and test

# %%
print (X_test_final.shape)
print (X_train_final.shape)
print (y_test.shape)
print (y_train.shape)
# Out:
# (336240, 33)
# (1344958, 33)
# (336240, 1)
# (1344958, 1)

# %% [markdown]
# ## MODEL CREATION

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=500,criterion='gini',random_state=4,max_depth=9)

# %%
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train_final,y_train.values.ravel() )
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=500, random_state=4)

# %%
y_pred=clf.predict(X_test_final)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5345021413276231

# %%
from sklearn.metrics import classification_report

# %%
print (classification_report(y_test,y_pred))
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.41      0.07      0.12    105682
#            1       0.00      0.00      0.00     31477
#            2       0.75      0.00      0.00     14662
#            3       0.95      0.20      0.33      9543
#            4       0.54      0.97      0.69    174876
#
#     accuracy                           0.53    336240
#    macro avg       0.53      0.25      0.23    336240
# weighted avg       0.47      0.53      0.41    336240
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
